# %%
import os
import os.path
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA, TruncatedSVD
#from matplotlib.image import imread
import skimage
from skimage.io import imread
import glob
from skimage import io
import pandas as pd
import warnings
from PIL import Image, ImageOps
import pathlib
import pickle
import csv

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
warnings.filterwarnings('ignore')

# %%
def process_image(img_path: str) -> np.array:
    img = Image.open(img_path)
    img = ImageOps.grayscale(img)
    img = np.ravel(img)
    img = np.ravel(img) / 255.0
    return img

# %%
def process_folder(folder: pathlib.PosixPath) -> pd.DataFrame:
    # We'll store the images here
    processed = []
    
    # For every image in the directory
    for img in folder.iterdir():
        # Ensure PGM
        if img.suffix == '.pgm':
            try:
                processed.append(process_image(img_path=str(img)))
            except Exception as _:
                continue
           
    # Convert to pd.DataFrame
    processed = pd.DataFrame(processed)
    return processed

# %%
dataframe1 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB01'))
dataframe2 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB02'))
dataframe3 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB03'))
dataframe4 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB04'))
dataframe5 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB05'))
dataframe6 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB06'))
dataframe7 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB07'))
dataframe8 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB08'))
dataframe9 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB09'))
dataframe10 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB10'))
dataframe11 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB11'))
dataframe12 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB12'))
dataframe13 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB13'))
dataframe15 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB15'))
dataframe16 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB16'))
dataframe17 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB17'))
dataframe18 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB18'))
dataframe19 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB19'))
dataframe20 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB20'))
dataframe21 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB21'))
dataframe22 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB22'))
dataframe23 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB23'))
dataframe24 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB24'))
dataframe25 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB25'))
dataframe26 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB26'))
dataframe27 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB27'))
dataframe28 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB28'))
dataframe29 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB29'))
dataframe30 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB30'))
dataframe31 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB31'))
dataframe32 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB32'))
dataframe33 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB33'))
dataframe34 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB34'))
dataframe35 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB35'))
dataframe36 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB36'))
dataframe37 = process_folder(folder=pathlib.Path.cwd().joinpath('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB37'))



dataframe = pd.concat([dataframe1,dataframe2,dataframe3,dataframe4,dataframe5,dataframe6,
                       dataframe7,dataframe8,dataframe9,dataframe10,dataframe11,dataframe12,
                       dataframe13,dataframe15,dataframe16,dataframe17,
                       dataframe18,dataframe19,dataframe20,dataframe21,dataframe22,
                       dataframe23,dataframe24,dataframe25,dataframe26,dataframe27,
                       dataframe28,dataframe29,dataframe30,dataframe31,dataframe32,
                       dataframe33,dataframe34,dataframe35,dataframe36,dataframe37],axis=0)

# %%
dataframe = dataframe.T
dataframe = dataframe.reset_index(drop=True)

# %%
mean_dataframe = dataframe.mean(axis=1)
for x in dataframe.columns:
    dataframe[x] = dataframe[x] - mean_dataframe

# %%
#Convert Mean Column Dataframe back to an Array
mean_arr=np.array(mean_dataframe)

#Reshape Mean Array to Original Image Dimensions
mean_arr1=mean_arr.reshape(192,168)

plt.title("Average Face")
plt.imshow(mean_arr1, cmap="gray")
plt.axis('off')
plt.show()

#SVD 
U, S, V = np.linalg.svd(dataframe, full_matrices=0)
U=np.array(U)
V=np.array(V)


#Plotting Eigenfaces
for j in range (0,36):
    for i in range (j,j+1):
        eigenface=np.reshape(U[:,i],(192,168))
        plt.title("Eigenface "+str(i+1))
        plt.imshow(eigenface, cmap="gray")
        plt.axis('off')
        plt.show()

# %%
fig3 = plt.figure(figsize=(10, 5), tight_layout=True)
ax1 = fig3.add_subplot(121)
ax1.semilogy(S,'-o',color='k')
ax1.set(xlabel='r', ylabel='Singular values $\sigma{}_r$')
ax2 = fig3.add_subplot(122)
ax2.plot(np.cumsum(S)/np.sum(S),'-o',color='k')
ax2.set(xlabel='r', ylabel='Cumulative energy')

# plt.savefig('../LaTeX/figures/singularValues.pdf')
plt.show()

# %%
temp1 = process_image('/Users/nishantabaral/Desktop/DataDriven Projects/CroppedYale/YaleB38/yaleB38_P00A-035E-20.pgm')
original_face=np.reshape(temp1,(192,168))
plt.title("Original face ")
plt.imshow(original_face, cmap="gray")
plt.axis('off')
plt.show()

# %%
testFaceMS = temp1 - mean_arr
r_list = [25, 50,100,200,400, 800, 1600]

for r in r_list:
    reconFace = mean_arr + U[:,:r] @ U[:,:r].T @ testFaceMS
    img = plt.imshow(np.reshape(reconFace,(192,168)))
    img.set_cmap('gray')
    plt.title('r = ' + str(r))
    plt.axis('off')
    plt.show()

# %%
def process_image(img_path: str) -> np.array:
    img = Image.open(img_path)
    img = ImageOps.grayscale(img)
    img = img.resize(size=(168, 192))
    img = np.ravel(img)
    img = np.ravel(img) / 255.0
    return img


temp1 = process_image('/Users/nishantabaral/Desktop/DataDriven Projects/mydog.jpg')
original_face=np.reshape(temp1,(192,168))
plt.title("Original face ")
plt.imshow(original_face, cmap="gray")
plt.axis('off')
plt.show()

# %%
testFaceMS = temp1 - mean_arr
r_list = [25, 50,100,200,400, 800, 1600]

for r in r_list:
    reconFace = mean_arr + U[:,:r] @ U[:,:r].T @ testFaceMS
    img = plt.imshow(np.reshape(reconFace,(192,168)))
    img.set_cmap('gray')
    plt.title('r = ' + str(r))
    plt.axis('off')
    plt.show()

# %%
def process_image(img_path: str) -> np.array:
    img = Image.open(img_path)
    img = ImageOps.grayscale(img)
    img = img.resize(size=(168, 192))
    img = np.ravel(img)
    img = np.ravel(img) / 255.0
    return img


temp1 = process_image('/Users/nishantabaral/Desktop/DataDriven Projects/chocolates.jpg')
original_face=np.reshape(temp1,(192,168))
plt.title("Original image ")
plt.imshow(original_face, cmap="gray")
plt.axis('off')
plt.show()

# %%
testFaceMS = temp1 - mean_arr
r_list = [25, 50,100,200,400, 800, 1600]

for r in r_list:
    reconFace = mean_arr + U[:,:r] @ U[:,:r].T @ testFaceMS
    img = plt.imshow(np.reshape(reconFace,(192,168)))
    img.set_cmap('gray')
    plt.title('r = ' + str(r))
    plt.axis('off')
    plt.show()
